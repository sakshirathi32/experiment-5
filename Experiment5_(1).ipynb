# %% [markdown]
# #Experiment 5 - Study of Python Dictionaries
# ##sakshi rathi / 25070123129

# %%
#creation of Dictionary
thisdict={'brand':'Ford','model':'Mustang','year':1964}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
# It takes latest value given for key. It will not allow duplicates
thisdict={'brand':'Ford','model':'Mustang','year':1964,'year':2020}
print(thisdict)
len(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}
# 3

# %%
thisdict={'brand':'Ford','model':'Mustang','year':1964}
len(thisdict)
# Out:
# 3

# %%
car={'brand':'Ford','model':'Mustang','year':1964}
car['color']='red'
print(car)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %%
car={'brand':'Ford','model':'Mustang','year':1964,'color':'red'}
print(car)
print(car.values())
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}
# dict_values(['Ford', 'Mustang', 1964, 'red'])

# %%
car={'brand':'Ford','model':'Mustang','year':1964,'color':'red'}
print(type(car))
print(car)
print(car.values())
# Out:
# <class 'dict'>
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}
# dict_values(['Ford', 'Mustang', 1964, 'red'])

# %%
student={'roll':101,'name':'Amit','branch':'E&TC'}
print('Name:',student['name'])
# Out:
# Name: Amit

# %%
#removing elements
student={'roll':101,'name':'Amit','branch':'E&TC'}
student.pop('branch')
print(student)
# Out:
# {'roll': 101, 'name': 'Amit'}

# %%
'''1: Updating Value'''
Product={'Pen':10,'Book':50,'Scale':20,'Book':55}
print('New product prices',Product)
# Out:
# New product prices {'Pen': 10, 'Book': 55, 'Scale': 20}

# %%
'''1: Updating Value'''
Product={'Pen':10,'Book':50,'Scale':20}
print('Original product prices',Product)
Product['Pen']=15
print('New product prices',Product)
# Out:
# Original product prices {'Pen': 10, 'Book': 50, 'Scale': 20}
# New product prices {'Pen': 15, 'Book': 50, 'Scale': 20}

# %%
'''2: Student Database'''
marks={'A':82,'B':60,'C':52}
name=input('Enter Name:')
print(marks.get(name,'Student not found'))
# Out:
# Enter Name:C
# 52

# %%
'''2: Student Database'''
marks={'A':82,'B':60,'C':52}
name=input('Enter Name:')
print(marks.get(name,'Student not found'))
# Out:
# Enter Name:d
# Student not found

# %%
'''3: Password Validation'''
users={'admin':'1234','student':'abcd'}
user_name=input('Enter username:')
password=input('Enter password:')
if users.get(user_name)==password:
  print('Login Successful')
else:
  print('Invalid Username or Password')
# Out:
# Enter username:admin
# Enter password:4321
# Invalid Username or Password

# %%
'''3: Password Validation'''
users={'admin':'1234','student':'abcd'}
user_name=input('Enter username:')
password=input('Enter password:')
if users.get(user_name)==password:
  print('Login Successful')
else:
  print('Invalid Username or Password')
# Out:
# Enter username:student
# Enter password:abcd
# Login Successful

# %%
'''4: Highest Score'''
marks={'A':82,'B':60,'C':52}
topper=max(marks,key=marks.get)
print('Topper:',topper)
print('Marks:',marks[topper])
# Out:
# Topper: A
# Marks: 82
